# %% [markdown]
# ### 對於地址相同且經緯度距離在 20 公尺以內的記錄，僅保留一筆

# %%
import numpy as np
import pandas as pd

def haversine_distance(lat1, lon1, lat2, lon2):
    """
    計算兩點經緯度之間的距離（單位：公尺）
    """
    R = 6371000  # 地球半徑 (公尺)
    
    # 將角度轉為弧度
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    dphi = np.radians(lat2 - lat1)
    dlambda = np.radians(lon2 - lon1)
    
    # Haversine 公式
    a = np.sin(dphi / 2)**2 + np.cos(phi1) * np.cos(phi2) * np.sin(dlambda / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    
    return R * c

def filter_close_points(group, threshold=20):
    """
    接收一個 group (同一個 address 的資料)，回傳需要保留的 index
    """
    
    # 解析經緯度 "119.884910,31.235518" -> lon, lat
    # 注意：split後轉float
    coords = group['location'].str.split(',', expand=True).astype(float)
    lons = coords[0].values  # 經度
    lats = coords[1].values  # 緯度
    indices = group.index.values
    
    keep_indices = []
    dropped_mask = np.zeros(len(group), dtype=bool) # 標記是否已被剔除
    
    for i in range(len(group)):
        if dropped_mask[i]:
            continue
            
        # 保留當前這一筆 (作為基準點)
        keep_indices.append(indices[i])
        
        # 計算當前點 (i) 與所有點的距離
        dists = haversine_distance(lats[i], lons[i], lats, lons)
        
        # 找出距離小於門檻值且尚未被處理的點 (包含自己，但沒關係因為loop會往下跑)
        # 標記這些點為 "已剔除" (因為它們離基準點太近了)
        close_hits = np.where(dists <= threshold)[0]
        dropped_mask[close_hits] = True
        
    return keep_indices

# %% [markdown]
# ### 商务住宅

# %%
# 1. 讀取 CSV (請確認編碼，中文常是 utf-8-sig 或 gb18030)
file_path = 'Yixing_data/2024_江苏省_无锡市_宜兴市_商务住宅.csv'  # 你的檔案名稱
try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')


# 1. 對 address 進行 groupby
# 2. 對每個 group 應用篩選邏輯
# 3. 收集所有要保留的 index
indices_to_keep = []
for name, group in df.groupby('address'):
    indices_to_keep.extend(filter_close_points(group))

# 取得最終結果
final_df = df.loc[indices_to_keep].sort_index()

print("原始筆數:", len(df))
print("篩選後筆數:", len(final_df))
print(final_df)
# Out:
# 原始筆數: 1305
# 篩選後筆數: 1299
#                                         id pname   pcode cityname  citycode  \
# 0     3afcb146-d32d-3622-8838-5e6025dfcffa   江苏省  320000      无锡市       510
# 1     ef1ac6e5-99f4-3cab-8b71-1860d3b4825b   江苏省  320000      无锡市       510
# 2     59474927-1d35-3859-bd15-ec527d7f06a3   江苏省  320000      无锡市       510
# 3     6e2c351f-8dfe-302b-8b68-e5932c16ee8a   江苏省  320000      无锡市       510
# 4     c295a58b-d914-3463-8c76-207003da92de   江苏省  320000      无锡市       510
# ...                                    ...   ...     ...      ...       ...
# 1300  44c287df-eb4d-3ccf-b6ef-54c39acd3aad   江苏省  320000      无锡市       510
# 1301  383fc298-d3dc-3017-84ad-84aa0ba166c7   江苏省  320000      无锡市       510
# 1302  f348ff07-7bb4-3140-bc91-b342637f7436   江苏省  320000      无锡市       510
# 1303  ac88f801-98fc-3a45-8167-110b158cd3a0   江苏省  320000      无锡市       510
# 1304  907fb253-090b-3952-9583-e3b171f52850   江苏省  320000      无锡市       510
#
#      adname  adcode        name             address              location  \
# 0       宜兴市  320282        城市年代  蛟河桥步行街与公园路交叉口东北60米  119.815626,31.366130
# 1       宜兴市  320282          和苑     鹅洲东路与和建路交叉口北40米  119.896274,31.481514
# 2       宜兴市  320282        幸福家园    官新街与官新西街交叉口东北50米  119.710496,31.498017
# 3       宜兴市  320282  鲸塘社区党群服务中心               鲸塘街3号  119.633407,31.342673
# 4       宜兴市  320282       华香苑饭店         太华镇华杨北路195号  119.588598,31.182729
# ...     ...     ...         ...                 ...                   ...
# 1300    宜兴市  320282      百合工业园区  新岳路与绿园路辅路交叉口西南120米  119.756411,31.357453
# 1301    宜兴市  320282        都山六村   偶亭侯路与三木路交叉口西北480米  119.671821,31.495412
# 1302    宜兴市  320282       泰晶产业园   荆邑北路与凯旋路交叉口西南140米  119.870133,31.417154
# 1303    宜兴市  320282     新庄工业集中区    新西路与庆源大道交叉口北260米  119.909869,31.364344
# 1304    宜兴市  320282      春江花园C区     康明路与氿西路交叉口东220米  119.807753,31.397799
#
#       ... business_area  行业大类  行业中类            行业小类       typecode  \
# 0     ...            宜城  商务住宅   住宅区     住宅小区|体育休闲服务  120302|080300
# 1     ...            []  商务住宅   住宅区       住宅小区|生活服务  120302|071100
# 2     ...            []  商务住宅   住宅区       住宅小区|餐饮服务  120302|050100
# 3     ...            []  商务住宅   住宅区  社区中心|政府机构及社会团体  120304|130000
# 4     ...            []  商务住宅   住宅区       住宅小区|餐饮服务  120302|050100
# ...   ...           ...   ...   ...             ...            ...
# 1300  ...            []  商务住宅  产业园区            产业园区         120100
# 1301  ...            []  商务住宅   住宅区            住宅小区         120302
# 1302  ...            []  商务住宅  产业园区            产业园区         120100
# 1303  ...            []  商务住宅  产业园区            产业园区         120100
# 1304  ...            []  商务住宅   住宅区            住宅小区         120302
#
#                 timestamp   longitude   latitude    wgs84_经度   wgs84_纬度
# 0     2024-05-20 18:00:03  119.815626  31.366130  119.810772  31.368191
# 1     2024-02-01 22:23:48  119.896274  31.481514  119.891611  31.483659
# 2     2024-01-27 23:07:16  119.710496  31.498017  119.705500  31.500006
# 3     2024-07-13 10:56:10  119.633407  31.342673  119.628527  31.344834
# 4     2024-02-08 05:54:40  119.588598  31.182729  119.583732  31.184982
# ...                   ...         ...        ...         ...        ...
# 1300  2024-01-23 18:52:30  119.756411  31.357453  119.751429  31.359448
# 1301  2024-08-25 07:22:53  119.671821  31.495412  119.666875  31.497469
# 1302  2024-06-17 13:20:34  119.870133  31.417154  119.865429  31.419294
# 1303  2024-01-27 23:32:02  119.909869  31.364344  119.905227  31.366518
# 1304  2024-03-21 09:10:18  119.807753  31.397799  119.802873  31.399837
#
# [1299 rows x 21 columns]

# %%
import os
output_file = 'location_sites.csv'

# 檢查檔案是否存在
file_exists = os.path.exists(output_file)

final_df.to_csv(
    output_file, 
    mode='a',                # 追加模式
    index=False, 
    header=not file_exists,  # 若檔案存在則不寫標題
    encoding='utf-8-sig'
)

print(f"成功追加 {len(final_df)} 筆資料到 {output_file}")
# Out:
# 成功追加 1299 筆資料到 location_sites.csv

# %% [markdown]
# ### 交叉路口

# %%
# 1. 讀取 CSV (請確認編碼)
file_path = 'Yixing_data/2024_江苏省_无锡市_宜兴市_地名地址信息.csv' 
try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')

print(f"原始資料筆數: {len(df)}")

# ==========================================
# [新增邏輯]：只保留 "name" 中有 "交叉口" 的資料
# ==========================================
# na=False 參數確保如果 name 欄位是空值(NaN)，不會報錯，而是直接視為不包含
df = df[df['name'].str.contains('交叉口', na=False)]

print(f"包含'交叉口'的資料筆數: {len(df)}")


# 2. 對 address 進行 groupby
# 3. 對每個 group 應用篩選邏輯
indices_to_keep = []

# 因為前面已經篩選過 df，這裡的 group 就全都是包含 "交叉口" 的資料了
for name, group in df.groupby('address'):
    # 注意：請確保 filter_close_points 函式存在並能回傳 index list
    indices_to_keep.extend(filter_close_points(group))

# 4. 取得最終結果
final_df = df.loc[indices_to_keep].sort_index()

print("最終篩選後筆數:", len(final_df))
print(final_df)
# Out:
# 原始資料筆數: 6152
# 包含'交叉口'的資料筆數: 2941
# 最終篩選後筆數: 2328
#                                         id pname   pcode cityname  citycode  \
# 5     66443903-1565-34ef-a130-9be54de63463   江苏省  320000      无锡市       510
# 6     95647b34-0ee0-3dcd-aa3a-0de8e8ab1d16   江苏省  320000      无锡市       510
# 8     3e2a2e30-5548-36e0-818e-257ee18281ff   江苏省  320000      无锡市       510
# 9     b5d3351e-14e4-368c-a80b-d2e732225d94   江苏省  320000      无锡市       510
# 10    734d5425-359b-3704-8680-13c812678209   江苏省  320000      无锡市       510
# ...                                    ...   ...     ...      ...       ...
# 6040  17f4bcc1-362c-31c8-b815-626223093430   江苏省  320000      无锡市       510
# 6061  11bdc83e-9ea5-3a7c-97c6-d12d2b740bf5   江苏省  320000      无锡市       510
# 6063  299b49b6-b5eb-3095-85d5-88594ee8d2dc   江苏省  320000      无锡市       510
# 6082  f221a583-7f3f-3a21-a64c-328210195d15   江苏省  320000      无锡市       510
# 6087  46ce6f10-865a-3322-acca-d5564ea23acd   江苏省  320000      无锡市       510
#
#      adname  adcode                  name address              location  ...  \
# 5       宜兴市  320282          贝市路与342省道交叉口     宜兴市  119.972962,31.526658  ...
# 6       宜兴市  320282  S48沪宜高速与S48沪宜高速出口交叉口     宜兴市  119.972453,31.528308  ...
# 8       宜兴市  320282        贝市路与S48沪宜高速交叉口     宜兴市  119.971027,31.527256  ...
# 9       宜兴市  320282  S48沪宜高速与S48沪宜高速出口交叉口     宜兴市  119.969994,31.526481  ...
# 10      宜兴市  320282      贝市路与S48沪宜高速出口交叉口     宜兴市  119.969491,31.527623  ...
# ...     ...     ...                   ...     ...                   ...  ...
# 6040    宜兴市  320282            五星路与蒋南路交叉口     宜兴市  119.634898,31.406966  ...
# 6061    宜兴市  320282          水库路与311县道交叉口     宜兴市  119.692448,31.295239  ...
# 6063    宜兴市  320282           枫隐路与阳泉东路交叉口     宜兴市  119.850974,31.371110  ...
# 6082    宜兴市  320282           庄南路与徐张公路交叉口     宜兴市  119.634990,31.317600  ...
# 6087    宜兴市  320282           环湖北路与环湖路交叉口     宜兴市  119.580539,31.238180  ...
#
#      business_area    行业大类  行业中类 行业小类 typecode            timestamp  \
# 5               []  地名地址信息  交通地名  路口名   190302  2023-12-08 11:18:51
# 6               []  地名地址信息  交通地名  路口名   190302  2024-01-18 12:28:34
# 8               []  地名地址信息  交通地名  路口名   190302  2024-02-03 23:25:29
# 9               []  地名地址信息  交通地名  路口名   190302  2024-01-27 06:14:23
# 10              []  地名地址信息  交通地名  路口名   190302  2024-02-04 18:40:29
# ...            ...     ...   ...  ...      ...                  ...
# 6040            []  地名地址信息  交通地名  路口名   190302  2024-01-27 09:19:00
# 6061            []  地名地址信息  交通地名  路口名   190302  2024-02-09 17:18:43
# 6063            宜城  地名地址信息  交通地名  路口名   190302  2024-01-18 00:56:37
# 6082            []  地名地址信息  交通地名  路口名   190302  2024-01-28 05:01:12
# 6087            []  地名地址信息  交通地名  路口名   190302  2024-02-06 12:01:22
#
#        longitude   latitude    wgs84_经度   wgs84_纬度
# 5     119.972962  31.526658  119.968239  31.528690
# 6     119.972453  31.528308  119.967731  31.530341
# 8     119.971027  31.527256  119.966309  31.529293
# 9     119.969994  31.526481  119.965278  31.528521
# 10    119.969491  31.527623  119.964776  31.529665
# ...          ...        ...         ...        ...
# 6040  119.634898  31.406966  119.630010  31.409105
# 6061  119.692448  31.295239  119.687490  31.297313
# 6063  119.850974  31.371110  119.846225  31.373235
# 6082  119.634990  31.317600  119.630110  31.319768
# 6087  119.580539  31.238180  119.575658  31.240402
#
# [2328 rows x 21 columns]

# %%
import os
output_file = 'location_sites.csv'

# 檢查檔案是否存在
file_exists = os.path.exists(output_file)

final_df.to_csv(
    output_file, 
    mode='a',                # 追加模式
    index=False, 
    header=not file_exists,  # 若檔案存在則不寫標題
    encoding='utf-8-sig'
)

print(f"成功追加 {len(final_df)} 筆醫療類資料到 {output_file}")
# Out:
# 成功追加 2328 筆醫療類資料到 location_sites.csv

# %% [markdown]
# ###  交通设施服务

# %%
# 1. 讀取 CSV (請確認編碼)
file_path = 'Yixing_data/2024_江苏省_无锡市_宜兴市_交通设施服务.csv' 
try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')


# 1. 對 address 進行 groupby
# 2. 對每個 group 應用篩選邏輯
# 3. 收集所有要保留的 index
indices_to_keep = []
for name, group in df.groupby('address'):
    indices_to_keep.extend(filter_close_points(group))

# 取得最終結果
final_df = df.loc[indices_to_keep].sort_index()

print("原始筆數:", len(df))
print("篩選後筆數:", len(final_df))
print(final_df)
# Out:
# 原始筆數: 4688
# 篩選後筆數: 4422
#                                         id pname   pcode cityname  citycode  \
# 0     0eb6c516-de4b-3f2a-8334-97d0d4233cc0   江苏省  320000      无锡市       510
# 1     45040083-35a2-36a9-b745-2358d62136ea   江苏省  320000      无锡市       510
# 2     ab50f415-f699-3d2b-9116-d1f11c1b09c1   江苏省  320000      无锡市       510
# 3     d753b460-3a98-346e-aea3-9bbc78dad7e6   江苏省  320000      无锡市       510
# 4     a5809f64-c349-37e6-aad8-c5befc34ee58   江苏省  320000      无锡市       510
# ...                                    ...   ...     ...      ...       ...
# 4683  c61f0748-fc59-3031-b261-3b98155e3dff   江苏省  320000      无锡市       510
# 4684  9e5bf9b8-e4a9-3153-bb19-bc6eebc485b6   江苏省  320000      无锡市       510
# 4685  f72b70d8-c5cb-33ba-baf7-9c1b94f67cc9   江苏省  320000      无锡市       510
# 4686  652462f9-7111-3168-b892-5c1d17e80c35   江苏省  320000      无锡市       510
# 4687  4e574828-5e5e-3531-9741-0c9cad46d228   江苏省  320000      无锡市       510
#
#      adname  adcode        name               address              location  \
# 0       宜兴市  320282   前红路-道路停车位      前红路与骏马路交叉口西北200米  119.870457,31.453918
# 1       宜兴市  320282   环保基地(公交站)  宜兴222路;宜兴225路;宜兴226路  119.870732,31.449668
# 2       宜兴市  320282       地面停车场        前红路与骏马路交叉口西40米  119.871918,31.453265
# 3       宜兴市  320282  地面停车场(出入口)                 地面停车场  119.871918,31.453265
# 4       宜兴市  320282     前红(公交站)  宜兴222路;宜兴225路;宜兴226路  119.872696,31.453516
# ...     ...     ...         ...                   ...                   ...
# 4683    宜兴市  320282       中洋山水画             万石中首国际石材城  119.942448,31.479535
# 4684    宜兴市  320282     庄前(公交站)                宜兴397路  119.705516,31.412413
# 4685    宜兴市  320282    寺前村(公交站)                宜兴303路  119.706662,31.318650
# 4686    宜兴市  320282    临时站(公交站)                宜兴385路  120.022580,31.471802
# 4687    宜兴市  320282     红岭(公交站)                宜兴206路  119.702643,31.228110
#
#       ... business_area    行业大类  行业中类    行业小类 typecode            timestamp  \
# 0     ...            []  交通设施服务   停车场   路边停车场   150906  2024-01-18 04:15:42
# 1     ...            []  交通设施服务  公交车站  公交车站相关   150700  2024-07-17 00:11:01
# 2     ...            []  交通设施服务   停车场   公共停车场   150904  2024-01-20 11:15:23
# 3     ...            []  交通设施服务   停车场  停车场出入口   150909  2024-01-24 20:14:57
# 4     ...            []  交通设施服务  公交车站  公交车站相关   150700  2024-07-18 00:58:50
# ...   ...           ...     ...   ...     ...      ...                  ...
# 4683  ...            []  交通设施服务   停车场   公共停车场   150904  2024-01-23 07:05:18
# 4684  ...            []  交通设施服务  公交车站  公交车站相关   150700  2024-08-15 07:12:16
# 4685  ...            []  交通设施服务  公交车站  公交车站相关   150700  2024-07-05 12:52:27
# 4686  ...            []  交通设施服务  公交车站  公交车站相关   150700  2024-07-23 20:43:29
# 4687  ...            []  交通设施服务  公交车站  公交车站相关   150700  2024-07-16 19:25:54
#
#        longitude   latitude    wgs84_经度   wgs84_纬度
# 0     119.870457  31.453918  119.865751  31.456050
# 1     119.870732  31.449668  119.866027  31.451801
# 2     119.871918  31.453265  119.867215  31.455398
# 3     119.871918  31.453265  119.867215  31.455398
# 4     119.872696  31.453516  119.867995  31.455650
# ...          ...        ...         ...        ...
# 4683  119.942448  31.479535  119.937784  31.481645
# 4684  119.705516  31.412413  119.700532  31.414427
# 4685  119.706662  31.318650  119.701685  31.320692
# 4686  120.022580  31.471802  120.017736  31.473696
# 4687  119.702643  31.228110  119.697678  31.230196
#
# [4422 rows x 21 columns]

# %%
import os
output_file = 'location_sites.csv'

# 檢查檔案是否存在
file_exists = os.path.exists(output_file)

final_df.to_csv(
    output_file, 
    mode='a',                # 追加模式
    index=False, 
    header=not file_exists,  # 若檔案存在則不寫標題
    encoding='utf-8-sig'
)

print(f"成功追加 {len(final_df)} 筆醫療類資料到 {output_file}")
# Out:
# 成功追加 4422 筆醫療類資料到 location_sites.csv

# %% [markdown]
# ### 医疗保健服务

# %%
file_path = 'Yixing_data/2024_江苏省_无锡市_宜兴市_医疗保健服务.csv'
try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')


# 1. 對 address 進行 groupby
# 2. 對每個 group 應用篩選邏輯
# 3. 收集所有要保留的 index
indices_to_keep = []
for name, group in df.groupby('address'):
    indices_to_keep.extend(filter_close_points(group))

# 取得最終結果
final_df = df.loc[indices_to_keep].sort_index()

print("原始筆數:", len(df))
print("篩選後筆數:", len(final_df))
print(final_df)
# Out:
# 原始筆數: 2279
# 篩選後筆數: 2206
#                                         id pname   pcode cityname  citycode  \
# 0     85ce1b43-d360-375c-983a-010634ffb69c   江苏省  320000      无锡市       510
# 1     2b9ac8db-b65b-36d5-adc5-c3f9f1b58f29   江苏省  320000      无锡市       510
# 2     bc0aa821-9dd4-324d-b0a2-98f2e8d83233   江苏省  320000      无锡市       510
# 3     cae65fb6-4baf-3326-8b3e-f8ca59761ae4   江苏省  320000      无锡市       510
# 4     091e1bc5-9fa5-3be7-b606-f5221edf20a0   江苏省  320000      无锡市       510
# ...                                    ...   ...     ...      ...       ...
# 2274  c441b38e-9743-35a2-842c-b465bb2bce79   江苏省  320000      无锡市       510
# 2275  a3c0cb23-0635-3edf-89c0-376c3066597d   江苏省  320000      无锡市       510
# 2276  31b7d6fd-8556-3fe7-9b45-841758c533fe   江苏省  320000      无锡市       510
# 2277  f28c6cb2-d182-3900-8b8d-5d220c128314   江苏省  320000      无锡市       510
# 2278  03bf4e53-1808-3118-86b4-18f6459f8df9   江苏省  320000      无锡市       510
#
#      adname  adcode              name           address              location  \
# 0       宜兴市  320282  宜兴市屺亭街道五星社区卫生服务站    北街路与五星路交叉口西80米  119.876237,31.438430
# 1       宜兴市  320282             嘉辉大药房               北街路  119.875518,31.438247
# 2       宜兴市  320282            白氏内科诊所         北街路五星花园2期  119.874904,31.437613
# 3       宜兴市  320282        夏芳社区卫生服务中心    兴业街与五凤街交叉口南80米  119.949316,31.440250
# 4       宜兴市  320282    高济天健医药连锁(扶风药店)    芳桥街道夏芳村兴业街861号  119.949213,31.440179
# ...     ...     ...               ...               ...                   ...
# 2274    宜兴市  320282               保健品  龙珠路与华杨北路交叉口东南40米  119.589247,31.179691
# 2275    宜兴市  320282               仁得康  万安路与张边路交叉口东南180米  119.851946,31.252614
# 2276    宜兴市  320282         无限极(张边路店)    紫荆新村东风苑东南门东60米  119.848793,31.251952
# 2277    宜兴市  320282            润身堂养生馆          仙都浴室西南门旁  119.848822,31.251965
# 2278    宜兴市  320282          宜丰卫生院-急诊   徐舍镇振丰东路52号宜丰卫生院  119.703388,31.407845
#
#       ... business_area    行业大类      行业中类      行业小类 typecode  \
# 0     ...            []  医疗保健服务      综合医院       卫生院    90102
# 1     ...            []  医疗保健服务   医药保健销售店        药房    90601
# 2     ...            []  医疗保健服务        诊所        诊所    90300
# 3     ...            []  医疗保健服务      综合医院       卫生院    90102
# 4     ...            []  医疗保健服务   医药保健销售店        药房    90601
# ...   ...           ...     ...       ...       ...      ...
# 2274  ...            []  医疗保健服务   医药保健销售店    医疗保健用品    90602
# 2275  ...            []  医疗保健服务  医疗保健服务场所  医疗保健服务场所    90000
# 2276  ...            []  医疗保健服务   医药保健销售店    医疗保健用品    90602
# 2277  ...            []  医疗保健服务  医疗保健服务场所  医疗保健服务场所    90000
# 2278  ...            []  医疗保健服务  医疗保健服务场所  医疗保健服务场所    90000
#
#                 timestamp   longitude   latitude    wgs84_经度   wgs84_纬度
# 0     2024-01-28 07:22:37  119.876237  31.438430  119.871545  31.440571
# 1     2024-07-27 18:26:36  119.875518  31.438247  119.870824  31.440388
# 2     2024-07-27 23:02:24  119.874904  31.437613  119.870209  31.439753
# 3     2024-02-08 16:14:59  119.949316  31.440250  119.944646  31.442354
# 4     2024-07-04 17:17:59  119.949213  31.440179  119.944543  31.442284
# ...                   ...         ...        ...         ...        ...
# 2274  2024-02-27 17:10:01  119.589247  31.179691  119.584382  31.181946
# 2275  2024-05-26 01:12:36  119.851946  31.252614  119.847210  31.254785
# 2276  2024-07-04 16:25:34  119.848793  31.251952  119.844048  31.254118
# 2277  2024-08-28 16:04:33  119.848822  31.251965  119.844077  31.254131
# 2278  2024-06-25 05:21:43  119.703388  31.407845  119.698406  31.409864
#
# [2206 rows x 21 columns]

# %%
import os
output_file = 'location_sites.csv'

# 檢查檔案是否存在
file_exists = os.path.exists(output_file)

final_df.to_csv(
    output_file, 
    mode='a',                # 追加模式
    index=False, 
    header=not file_exists,  # 若檔案存在則不寫標題
    encoding='utf-8-sig'
)

print(f"成功追加 {len(final_df)} 筆醫療類資料到 {output_file}")
# Out:
# 成功追加 2206 筆醫療類資料到 location_sites.csv

# %% [markdown]
# ### 政府機構

# %%
file_path = 'Yixing_data/2024_江苏省_无锡市_宜兴市_政府机构及社会团体.csv'

try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')


# 1. 對 address 進行 groupby
# 2. 對每個 group 應用篩選邏輯
# 3. 收集所有要保留的 index
indices_to_keep = []
for name, group in df.groupby('address'):
    indices_to_keep.extend(filter_close_points(group))

# 取得最終結果
final_df = df.loc[indices_to_keep].sort_index()

print("原始筆數:", len(df))
print("篩選後筆數:", len(final_df))
print(final_df)
# Out:
# 原始筆數: 3243
# 篩選後筆數: 2714
#                                         id pname   pcode cityname  citycode  \
# 0     6e151fd2-21d0-31d2-b3ce-fbda303da55c   江苏省  320000      无锡市       510
# 1     d6ae2ba1-a392-35e7-8a07-60051e78049c   江苏省  320000      无锡市       510
# 2     a8cffc7d-9a17-3aac-9dc1-8a82bedcf4c4   江苏省  320000      无锡市       510
# 3     6524a580-1dab-36cc-93fb-c1d157984421   江苏省  320000      无锡市       510
# 4     4880de78-3971-3669-af85-3bcd15bc06ac   江苏省  320000      无锡市       510
# ...                                    ...   ...     ...      ...       ...
# 3238  76135efe-ab4f-3c0d-b425-6b4627c41e3e   江苏省  320000      无锡市       510
# 3239  cc3febd6-9ed3-384b-82d2-669b41d7bc8f   江苏省  320000      无锡市       510
# 3240  9a6b27da-c90b-3752-b44a-762af84c3195   江苏省  320000      无锡市       510
# 3241  b7e79df5-3e6d-30e9-95ab-43035afd07d8   江苏省  320000      无锡市       510
# 3242  771e1d8f-6956-3cc5-ba8c-92b71a17279d   江苏省  320000      无锡市       510
#
#      adname  adcode                name              address  \
# 0       宜兴市  320282    宜兴市市场监督管理局老干部活动室           陶都路218-222
# 1       宜兴市  320282            交通事故快速理赔     氿滨大道与谢桥路交叉口西南60米
# 2       宜兴市  320282     宜城街道下漳社区劳动保障工作站             宜城街道下漳社区
# 3       宜兴市  320282  宜兴市自然资源和规划局林场国土资源所   314县道与312县道交叉口东60米
# 4       宜兴市  320282      江苏省华东石材市场管理委员会                  万石镇
# ...     ...     ...                 ...                  ...
# 3238    宜兴市  320282        丁蜀派出所丁蜀警务工作站    公园中路与白宕南路交叉口西140米
# 3239    宜兴市  320282          中合汽车检测年审中心   230省道与通蜀东路交叉口西南20米
# 3240    宜兴市  320282       瑞德蔬菜果品批发市场警务室  瑞德蔬菜果品批发市场西南2门东210米
# 3241    宜兴市  320282                 警务站   313县道与邮五线交叉口西北160米
# 3242    宜兴市  320282              周铁人民法庭              周铁镇渎边公路
#
#                   location  ... business_area       行业大类    行业中类  \
# 0     119.821575,31.346231  ...            宜城  政府机构及社会团体    政府机关
# 1     119.806645,31.346183  ...            []  政府机构及社会团体  交通车辆管理
# 2     119.843476,31.364791  ...            宜城  政府机构及社会团体    政府机关
# 3     119.728751,31.249887  ...            []  政府机构及社会团体    政府机关
# 4     119.938576,31.485716  ...            []  政府机构及社会团体    政府机关
# ...                    ...  ...           ...        ...     ...
# 3238  119.840076,31.252157  ...            []  政府机构及社会团体   公检法机构
# 3239  119.897616,31.258386  ...            []  政府机构及社会团体  交通车辆管理
# 3240  119.807040,31.401611  ...            []  政府机构及社会团体   公检法机构
# 3241  119.620979,31.429882  ...            []  政府机构及社会团体   公检法机构
# 3242  120.002742,31.426786  ...            []  政府机构及社会团体   公检法机构
#
#                      行业小类       typecode            timestamp   longitude  \
# 0       区县级政府及事业单位|体育休闲服务  130104|080500  2024-02-08 11:27:15  119.821575
# 1           交通管理机构|金融保险服务  130601|160000  2024-08-24 18:58:10  119.806645
# 2     乡镇以下级政府及事业单位|体育休闲服务  130106|080500  2024-02-05 00:30:24  119.843476
# 3                  政府机关相关         130100  2024-01-24 02:26:56  119.728751
# 4                  政府机关相关         130100  2024-04-04 19:16:20  119.938576
# ...                   ...            ...                  ...         ...
# 3238                 公安警察         130501  2024-01-22 22:00:21  119.840076
# 3239                  验车场         130603  2023-12-08 02:20:06  119.897616
# 3240               社会治安机构         130506  2024-01-23 19:56:05  119.807040
# 3241               社会治安机构         130506  2024-01-22 20:02:06  119.620979
# 3242                   法院         130503  2023-12-08 10:46:07  120.002742
#
#        latitude    wgs84_经度   wgs84_纬度
# 0     31.346231  119.816740  31.348310
# 1     31.346183  119.801767  31.348235
# 2     31.364791  119.838706  31.366905
# 3     31.249887  119.723767  31.251932
# 4     31.485716  119.933915  31.487831
# ...         ...         ...        ...
# 3238  31.252157  119.835306  31.254307
# 3239  31.258386  119.892973  31.260601
# 3240  31.401611  119.802158  31.403647
# 3241  31.429882  119.616100  31.432032
# 3242  31.426786  119.997953  31.428749
#
# [2714 rows x 21 columns]

# %%
import os
output_file = 'location_sites.csv'

# 檢查檔案是否存在
file_exists = os.path.exists(output_file)

final_df.to_csv(
    output_file, 
    mode='a',                # 追加模式
    index=False, 
    header=not file_exists,  # 若檔案存在則不寫標題
    encoding='utf-8-sig'
)

print(f"成功追加 {len(final_df)} 筆政府机构資料到 {output_file}")
# Out:
# 成功追加 2714 筆政府机构資料到 location_sites.csv

# %% [markdown]
# ### 公共設施

# %%
file_path = 'Yixing_data/2024_江苏省_无锡市_宜兴市_公共设施.csv'

try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')


# 1. 對 address 進行 groupby
# 2. 對每個 group 應用篩選邏輯
# 3. 收集所有要保留的 index
indices_to_keep = []
for name, group in df.groupby('address'):
    indices_to_keep.extend(filter_close_points(group))

# 取得最終結果
final_df = df.loc[indices_to_keep].sort_index()

print("原始筆數:", len(df))
print("篩選後筆數:", len(final_df))
print(final_df)
# Out:
# 原始筆數: 566
# 篩選後筆數: 552
#                                        id pname   pcode cityname  citycode  \
# 0    35fd8a75-f4e7-368b-a475-8c93282e501c   江苏省  320000      无锡市       510
# 1    7d875ced-e88b-31c4-a9ca-633899e94bd0   江苏省  320000      无锡市       510
# 2    72594756-f6b7-3118-a5c9-b03f703bb319   江苏省  320000      无锡市       510
# 3    51410705-f08b-39e8-82f6-7db32c1144bb   江苏省  320000      无锡市       510
# 4    9b268842-f9ae-3977-9ccf-2b9a5eee197e   江苏省  320000      无锡市       510
# ..                                    ...   ...     ...      ...       ...
# 561  84a8acd6-7b00-39a6-a709-9d1b1a6899cc   江苏省  320000      无锡市       510
# 562  0ab4d759-f61c-36f6-9e6a-c1d5962f9417   江苏省  320000      无锡市       510
# 563  21316736-ec42-3b0f-a841-d1471bd6c9d8   江苏省  320000      无锡市       510
# 564  b15b72ef-9586-3049-b58b-d1ad24ce0ca1   江苏省  320000      无锡市       510
# 565  44830a8f-8439-3cfd-9aec-1bcb0c46da99   江苏省  320000      无锡市       510
#
#     adname  adcode        name              address              location  \
# 0      宜兴市  320282        公共厕所             解放中路105号  119.837025,31.256286
# 1      宜兴市  320282        公共厕所   解放东路与白宕中路交叉口东北180米  119.842733,31.257178
# 2      宜兴市  320282        公共厕所  丁蜀镇白宕中路画溪花园(紫砂宾馆东北)  119.841611,31.254752
# 3      宜兴市  320282        公共厕所   公园中路与丁山中路交叉口东北200米  119.837623,31.253438
# 4      宜兴市  320282        公共厕所             紫砂路南150米  119.835018,31.259695
# ..     ...     ...         ...                  ...                   ...
# 561    宜兴市  320282        公共厕所      周万路与王塘路交叉口西160米  119.976053,31.451218
# 562    宜兴市  320282         报刊亭     东横街与鹅洲东路交叉口西南50米  119.896093,31.482162
# 563    宜兴市  320282         报刊亭      中桥路与中兴路交叉口西北40米  119.862576,31.435329
# 564    宜兴市  320282  民防工程应急掩蔽场所     学府东路与学院路交叉口西北60米  119.871424,31.366460
# 565    宜兴市  320282         报刊亭             紫竹路20号附近  119.841409,31.377948
#
#      ... business_area  行业大类  行业中类  行业小类 typecode            timestamp  \
# 0    ...            []  公共设施  公共厕所  公共厕所   200300  2024-02-12 09:28:30
# 1    ...            []  公共设施  公共厕所  公共厕所   200300  2024-02-10 11:31:23
# 2    ...            []  公共设施  公共厕所  公共厕所   200300  2024-04-10 03:51:57
# 3    ...            []  公共设施  公共厕所  公共厕所   200300  2024-02-02 00:47:49
# 4    ...            []  公共设施  公共厕所  公共厕所   200300  2024-02-10 10:23:56
# ..   ...           ...   ...   ...   ...      ...                  ...
# 561  ...            []  公共设施  公共厕所  公共厕所   200300  2024-01-18 03:05:42
# 562  ...            []  公共设施   报刊亭   报刊亭   200100  2024-02-16 16:21:46
# 563  ...            []  公共设施   报刊亭   报刊亭   200100  2024-08-16 12:18:21
# 564  ...            []  公共设施  公共设施  公共设施   200000  2024-01-27 09:47:18
# 565  ...            宜城  公共设施   报刊亭   报刊亭   200100  2024-08-16 12:19:19
#
#       longitude   latitude    wgs84_经度   wgs84_纬度
# 0    119.837025  31.256286  119.832245  31.258429
# 1    119.842733  31.257178  119.837970  31.259331
# 2    119.841611  31.254752  119.836845  31.256904
# 3    119.837623  31.253438  119.832845  31.255583
# 4    119.835018  31.259695  119.830232  31.261833
# ..          ...        ...         ...        ...
# 561  119.976053  31.451218  119.971330  31.453254
# 562  119.896093  31.482162  119.891429  31.484307
# 563  119.862576  31.435329  119.857853  31.437454
# 564  119.871424  31.366460  119.866728  31.368616
# 565  119.841409  31.377948  119.836632  31.380054
#
# [552 rows x 21 columns]

# %%
import os
output_file = 'location_sites.csv'

# 檢查檔案是否存在
file_exists = os.path.exists(output_file)

final_df.to_csv(
    output_file, 
    mode='a',                # 追加模式
    index=False, 
    header=not file_exists,  # 若檔案存在則不寫標題
    encoding='utf-8-sig'
)

print(f"成功追加 {len(final_df)} 筆政府机构資料到 {output_file}")
# Out:
# 成功追加 552 筆政府机构資料到 location_sites.csv

# %% [markdown]
# ### 廣場或公園

# %%
import pandas as pd

file_path = 'Yixing_data/2024_江苏省_无锡市_宜兴市_风景名胜.csv'

try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')

# ==========================================
# 新增步驟：先篩選 name 中包含特定關鍵字的資料
# ==========================================

# 定義關鍵字 (使用 | 符號代表 "或")
keywords = '公园|广场' 

# 建立遮罩 (Mask)：找出 name 欄位中包含這些字的列
# na=False 確保如果 name 是空的 (NaN) 不會報錯，直接視為 False
mask = df['name'].str.contains(keywords, na=False)

# 產生只包含公園或廣場的臨時 DataFrame
target_df = df[mask]


indices_to_keep = []

# 注意：這裡改成對 target_df (篩選後的資料) 進行 groupby
for name, group in target_df.groupby('address'):
    # 假設 filter_close_points 函式已經在上面定義好了
    indices_to_keep.extend(filter_close_points(group))

# 取得最終結果
# loc 會根據保留下來的 index 回到原始 df (或 target_df) 抓取資料
final_df = df.loc[indices_to_keep].sort_index()

print("原始總筆數:", len(df))
print(f"符合關鍵字 '{keywords}' 的筆數:", len(target_df))
print("經距離篩選後的最終筆數:", len(final_df))
print(final_df)
# Out:
# 原始總筆數: 679
# 符合關鍵字 '公园|广场' 的筆數: 107
# 經距離篩選後的最終筆數: 107
#                                        id pname   pcode cityname  citycode  \
# 0    31ca1582-f0ec-3d40-b77a-dcac77fc0601   江苏省  320000      无锡市       510
# 11   715b0d83-c323-3575-8f3f-d0bb4dbbcd8b   江苏省  320000      无锡市       510
# 21   626f667f-b235-3b6c-be22-d5b13247afd0   江苏省  320000      无锡市       510
# 26   7070b370-50c0-3fdf-ba3e-ce8575e99807   江苏省  320000      无锡市       510
# 27   32c09e56-1ebe-366e-80c8-96171aabf74d   江苏省  320000      无锡市       510
# ..                                    ...   ...     ...      ...       ...
# 636  d459d453-bc31-3882-97be-b5f503f70563   江苏省  320000      无锡市       510
# 638  8c5c1adf-87c3-35f8-b5ae-0a74266c6c43   江苏省  320000      无锡市       510
# 641  fabf1e4e-bce5-39c7-b198-574bd9024ee7   江苏省  320000      无锡市       510
# 650  d9b3aaa4-1b1c-36e2-bbf8-c148f2272046   江苏省  320000      无锡市       510
# 652  bf738b43-94b0-3c10-80f4-3912d629d10f   江苏省  320000      无锡市       510
#
#     adname  adcode          name               address              location  \
# 0      宜兴市  320282      文明乡风文化广场     三洞桥路与芳溪路交叉口东南120米  119.869997,31.248474
# 11     宜兴市  320282          龙溪公园                公园路77号  119.839316,31.249894
# 21     宜兴市  320282         城隍山公园                湖父镇大东村  119.803223,31.232086
# 26     宜兴市  320282     中心广场(蠡蜀路)                 蠡蜀路附近  119.848262,31.257688
# 27     宜兴市  320282  黄龙山地质公园(建设中)       紫砂路与民主路交叉口北100米  119.848246,31.260637
# ..     ...     ...           ...                   ...                   ...
# 636    宜兴市  320282        晨力体育广场     振兴路与塍东南路交叉口东南100米  119.817793,31.447686
# 638    宜兴市  320282     高塍村农民休闲广场       赛特大道高塍村农民文化活动中心  119.813107,31.442371
# 641    宜兴市  320282   龙背山森林公园·杜鹃园  宜城街道人民南路南端(龙背山森林公园内)  119.818093,31.324335
# 650    宜兴市  320282   丁山服务区法治文化广场   丁山服务区与104国道交叉口东120米  119.819782,31.267114
# 652    宜兴市  320282         青龙山公园       丁蜀镇东坡西路8号东南100米  119.835540,31.263655
#
#      ... business_area  行业大类    行业中类  行业小类 typecode            timestamp  \
# 0    ...            []  风景名胜    公园广场  城市广场   110105  2024-01-24 23:58:19
# 11   ...            []  风景名胜    公园广场    公园   110101  2024-07-29 12:22:41
# 21   ...            []  风景名胜    公园广场    公园   110101  2024-07-05 16:54:58
# 26   ...            []  风景名胜    公园广场  城市广场   110105  2024-08-23 16:03:56
# 27   ...            []  风景名胜    公园广场    公园   110101  2024-01-20 22:01:12
# ..   ...           ...   ...     ...   ...      ...                  ...
# 636  ...            []  风景名胜    公园广场  城市广场   110105  2023-12-07 21:50:35
# 638  ...            []  风景名胜    公园广场  城市广场   110105  2024-01-23 20:23:48
# 641  ...            []  风景名胜  风景名胜相关  旅游景点   110000  2024-08-14 16:28:15
# 650  ...            []  风景名胜    公园广场  公园广场   110100  2024-02-10 08:43:47
# 652  ...            []  风景名胜    公园广场    公园   110101  2024-09-05 07:20:04
#
#       longitude   latitude    wgs84_经度   wgs84_纬度
# 0    119.869997  31.248474  119.865308  31.250673
# 11   119.839316  31.249894  119.834544  31.252044
# 21   119.803223  31.232086  119.798345  31.234178
# 26   119.848262  31.257688  119.843515  31.259851
# 27   119.848246  31.260637  119.843499  31.262798
# ..          ...        ...         ...        ...
# 636  119.817793  31.447686  119.812938  31.449730
# 638  119.813107  31.442371  119.808239  31.444407
# 641  119.818093  31.324335  119.813250  31.326415
# 650  119.819782  31.267114  119.814949  31.269220
# 652  119.835540  31.263655  119.830755  31.265792
#
# [107 rows x 21 columns]

# %%
import os
output_file = 'location_sites.csv'

# 檢查檔案是否存在
file_exists = os.path.exists(output_file)

final_df.to_csv(
    output_file, 
    mode='a',                # 追加模式
    index=False, 
    header=not file_exists,  # 若檔案存在則不寫標題
    encoding='utf-8-sig'
)

print(f"成功追加 {len(final_df)} 筆政府机构資料到 {output_file}")
# Out:
# 成功追加 107 筆政府机构資料到 location_sites.csv

# %% [markdown]
# ### 總整理一次

# %%
file_path = 'location_sites.csv'

try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')


# 1. 對 address 進行 groupby
# 2. 對每個 group 應用篩選邏輯
# 3. 收集所有要保留的 index
indices_to_keep = []
for name, group in df.groupby('address'):
    indices_to_keep.extend(filter_close_points(group))

# 取得最終結果
final_df = df.loc[indices_to_keep].sort_index()

print("原始筆數:", len(df))
print("篩選後筆數:", len(final_df))
print(final_df)
# Out:
# 原始筆數: 13628
# 篩選後筆數: 13536
#                                          id pname   pcode cityname  citycode  \
# 0      3afcb146-d32d-3622-8838-5e6025dfcffa   江苏省  320000      无锡市       510
# 1      ef1ac6e5-99f4-3cab-8b71-1860d3b4825b   江苏省  320000      无锡市       510
# 2      59474927-1d35-3859-bd15-ec527d7f06a3   江苏省  320000      无锡市       510
# 3      6e2c351f-8dfe-302b-8b68-e5932c16ee8a   江苏省  320000      无锡市       510
# 4      c295a58b-d914-3463-8c76-207003da92de   江苏省  320000      无锡市       510
# ...                                     ...   ...     ...      ...       ...
# 13623  d459d453-bc31-3882-97be-b5f503f70563   江苏省  320000      无锡市       510
# 13624  8c5c1adf-87c3-35f8-b5ae-0a74266c6c43   江苏省  320000      无锡市       510
# 13625  fabf1e4e-bce5-39c7-b198-574bd9024ee7   江苏省  320000      无锡市       510
# 13626  d9b3aaa4-1b1c-36e2-bbf8-c148f2272046   江苏省  320000      无锡市       510
# 13627  bf738b43-94b0-3c10-80f4-3912d629d10f   江苏省  320000      无锡市       510
#
#       adname  adcode         name               address              location  \
# 0        宜兴市  320282         城市年代    蛟河桥步行街与公园路交叉口东北60米  119.815626,31.366130
# 1        宜兴市  320282           和苑       鹅洲东路与和建路交叉口北40米  119.896274,31.481514
# 2        宜兴市  320282         幸福家园      官新街与官新西街交叉口东北50米  119.710496,31.498017
# 3        宜兴市  320282   鲸塘社区党群服务中心                 鲸塘街3号  119.633407,31.342673
# 4        宜兴市  320282        华香苑饭店           太华镇华杨北路195号  119.588598,31.182729
# ...      ...     ...          ...                   ...                   ...
# 13623    宜兴市  320282       晨力体育广场     振兴路与塍东南路交叉口东南100米  119.817793,31.447686
# 13624    宜兴市  320282    高塍村农民休闲广场       赛特大道高塍村农民文化活动中心  119.813107,31.442371
# 13625    宜兴市  320282  龙背山森林公园·杜鹃园  宜城街道人民南路南端(龙背山森林公园内)  119.818093,31.324335
# 13626    宜兴市  320282  丁山服务区法治文化广场   丁山服务区与104国道交叉口东120米  119.819782,31.267114
# 13627    宜兴市  320282        青龙山公园       丁蜀镇东坡西路8号东南100米  119.835540,31.263655
#
#        ... business_area  行业大类    行业中类            行业小类       typecode  \
# 0      ...            宜城  商务住宅     住宅区     住宅小区|体育休闲服务  120302|080300
# 1      ...            []  商务住宅     住宅区       住宅小区|生活服务  120302|071100
# 2      ...            []  商务住宅     住宅区       住宅小区|餐饮服务  120302|050100
# 3      ...            []  商务住宅     住宅区  社区中心|政府机构及社会团体  120304|130000
# 4      ...            []  商务住宅     住宅区       住宅小区|餐饮服务  120302|050100
# ...    ...           ...   ...     ...             ...            ...
# 13623  ...            []  风景名胜    公园广场            城市广场         110105
# 13624  ...            []  风景名胜    公园广场            城市广场         110105
# 13625  ...            []  风景名胜  风景名胜相关            旅游景点         110000
# 13626  ...            []  风景名胜    公园广场            公园广场         110100
# 13627  ...            []  风景名胜    公园广场              公园         110101
#
#                  timestamp   longitude   latitude    wgs84_经度   wgs84_纬度
# 0      2024-05-20 18:00:03  119.815626  31.366130  119.810772  31.368191
# 1      2024-02-01 22:23:48  119.896274  31.481514  119.891611  31.483659
# 2      2024-01-27 23:07:16  119.710496  31.498017  119.705500  31.500006
# 3      2024-07-13 10:56:10  119.633407  31.342673  119.628527  31.344834
# 4      2024-02-08 05:54:40  119.588598  31.182729  119.583732  31.184982
# ...                    ...         ...        ...         ...        ...
# 13623  2023-12-07 21:50:35  119.817793  31.447686  119.812938  31.449730
# 13624  2024-01-23 20:23:48  119.813107  31.442371  119.808239  31.444407
# 13625  2024-08-14 16:28:15  119.818093  31.324335  119.813250  31.326415
# 13626  2024-02-10 08:43:47  119.819782  31.267114  119.814949  31.269220
# 13627  2024-09-05 07:20:04  119.835540  31.263655  119.830755  31.265792
#
# [13536 rows x 21 columns]
