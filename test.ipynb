# %%
import pandas as pd

file_path = 'mapped_data.csv'  # 你的檔案名稱
try:
    df = pd.read_csv(file_path, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='gb18030')

print(df.shape)
# Out:
# (70913, 22)

# %%
df['osm_tag'].unique()
# Out:
# array(['restaurant', 'cafe', 'fast food', 'ice cream', 'office',
#        'greenhouse', 'industrial', 'barn', 'parking', 'bus station',
#        'parking entrance', 'public', 'loading dock', 'bar', 'nightclub',
#        'sports centre', 'gambling', 'internet cafe', 'commercial',
#        'theatre', 'cinema', 'hospital', 'hotel', 'dojo', 'riding hall',
#        'clinic', 'pharmacy', 'dentist', 'veterinary', 'apartments',
#        'detached', 'dormitory', 'residential', 'service', 'warehouse',
#        'post office', 'retail', 'charging station', 'grave yard',
#        'training', 'arts centre', 'driving school', 'kindergarten',
#        'exhibition centre', 'school', 'college', 'library', 'university',
#        'marketplace'], dtype=object)
